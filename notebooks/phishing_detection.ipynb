# %% [markdown]
# # 🛡️ PhishGuard — ML Pipeline & Training
#
# This notebook contains the complete, reproducible machine learning pipeline for **PhishGuard**.
#
# ## Pipeline Overview
# 1. **Data Acquisition & Loading:** Load the PhiUSIIL Phishing URL Dataset.
# 2. **Data Cleaning & Preprocessing:** Validate URLs and handle missing values.
# 3. **Feature Engineering:** Extract 33 lexical and structural URL features
#    (see `ml/feature_extractor.py`).
# 4. **Model Training & Comparison:** Train Logistic Regression, Random Forest,
#    and XGBoost (canonical pipeline in `ml/train.py`).
# 5. **Model Evaluation:** Evaluate performance using Precision, Recall, F1-Score, ROC-AUC, and Confusion Matrix.
# 6. **Explainability (SHAP):** Compute global and local feature importance.
# 7. **Model Export:** Save trained model artifacts for server deployment.

# %%
import os
import sys
import json
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Robust project root path resolution
project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) if os.path.basename(os.getcwd()) == 'notebooks' else os.getcwd()
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from ml.feature_extractor import FeatureExtractor
from ml.explainer import PhishGuardExplainer

print('Setup complete. Root directory:', project_root)
# Out:
# Setup complete. Root directory: c:\coding-projects\phishguard

# %% [markdown]
# ## 1. Load Dataset
# Expected dataset file: `data/phishing_urls.csv` (See `data/README.md` for download instructions).

# %%
data_path = os.path.join(project_root, 'data', 'phishing_urls.csv')
if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    print(f'Dataset loaded successfully. Shape: {df.shape}')
else:
    print(f'Dataset not found at {data_path}. Please follow data/README.md to download it.')
# Out:
# Dataset loaded successfully. Shape: (235795, 55)
